# %%
from jplane_np import JuliaPlane
from jplane_np import julia

# %%
c = 0
P = JuliaPlane(c)
P.show()

# %%
c = -1
P = JuliaPlane(c)
P.show()

# %%
c = 0.3
P = JuliaPlane(c)
P.show()

# %%
c = -1.037 + 0.17*1j
P = JuliaPlane(c)
P.show()

# %%
c= -0.624 + 0.435*1j
P = JuliaPlane(c)
P.show()

# %%
c= -0.8 + 0.2*1j
P = JuliaPlane(c)
P.show()

# %%
c= -0.835 - 0.2321*1j
P = JuliaPlane(c)
P.show()
